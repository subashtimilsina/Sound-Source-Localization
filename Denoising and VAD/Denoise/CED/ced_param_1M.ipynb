# %% [markdown]
# ### Mount google drive to the colab

# %%
# comment this line if using local machine
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Importing necessary libraries

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

import pickle

# sklearn libraries
from sklearn.model_selection import train_test_split

# tensorflow/keras libraries
import keras
from keras.models import Sequential, load_model
from keras.layers import Conv2D, MaxPooling2D, Conv2DTranspose, Activation
from keras.layers import BatchNormalization
from keras.callbacks import EarlyStopping
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Data preparation and preprocessing

# %%
X_train =0 
y_train=0

i=0
j=5000
X_train = np.load("drive/My Drive/Project/Train/x_mag_500batch1.npy", mmap_mode='r')[i:i+j]
y_train = np.load("drive/My Drive/Project/Train/y_mag_500batch1.npy", mmap_mode='r')[i:i+j]

X_train = np.vstack((X_train,np.load("drive/My Drive/Project/Train/x_mag_500batch2.npy", mmap_mode='r')[i:i+j]))
y_train = np.vstack((y_train,np.load("drive/My Drive/Project/Train/y_mag_500batch2.npy", mmap_mode='r')[i:i+j]))

X_train = np.vstack((X_train,np.load("drive/My Drive/Project/Train/x_mag_500batch3.npy", mmap_mode='r')[i:i+j]))
y_train = np.vstack((y_train,np.load("drive/My Drive/Project/Train/y_mag_500batch3.npy", mmap_mode='r')[i:i+j]))

X_train = np.vstack((X_train,np.load("drive/My Drive/Project/Train/x_mag_500batch4.npy", mmap_mode='r')[i:i+j]))
y_train = np.vstack((y_train,np.load("drive/My Drive/Project/Train/y_mag_500batch4.npy", mmap_mode='r')[i:i+j]))

X_train = np.vstack((X_train,np.load("drive/My Drive/Project/Train/x_mag_500batch1_drone_full_noise.npy", mmap_mode='r')[i:i+j]))
y_train = np.vstack((y_train,np.load("drive/My Drive/Project/Train/y_mag_500batch1.npy", mmap_mode='r')[i:i+j]))

X_train = np.vstack((X_train,np.load("drive/My Drive/Project/Train/x_mag_500batch2_drone_full_noise.npy", mmap_mode='r')[i:i+j]))
y_train = np.vstack((y_train,np.load("drive/My Drive/Project/Train/y_mag_500batch2.npy", mmap_mode='r')[i:i+j]))

X_train = np.vstack((X_train,np.load("drive/My Drive/Project/Train/x_mag_500batch3_drone_full_noise.npy", mmap_mode='r')[i:i+j]))
y_train = np.vstack((y_train,np.load("drive/My Drive/Project/Train/y_mag_500batch3.npy", mmap_mode='r')[i:i+j]))

X_train = np.vstack((X_train,np.load("drive/My Drive/Project/Train/x_mag_500batch4_drone_full_noise.npy", mmap_mode='r')[i:i+j]))
y_train = np.vstack((y_train,np.load("drive/My Drive/Project/Train/y_mag_500batch4.npy", mmap_mode='r')[i:i+j]))

# %%
y = np.zeros((40000,1))
y[20000:40000] = 1

# %% [markdown]
# #### Creating train test split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size=0.2, shuffle=True, random_state=42, stratify=y)

# %% [markdown]
# ## Denoising model creation (CED)

# %%
model = Sequential()
model.add(Conv2D(64, kernel_size=(5,5),padding='valid',use_bias=True, kernel_initializer='glorot_uniform',bias_initializer='zeros'
                 ,data_format= "channels_first",input_shape=(8,129,17)))
model.add(BatchNormalization())#axis=1))
model.add(Activation('relu'))
model.add(Conv2D(64, (5,5),padding='valid',use_bias=True, kernel_initializer='glorot_uniform',bias_initializer='zeros',data_format= "channels_first"))
model.add(BatchNormalization())#axis=1))
model.add(Activation('relu'))
model.add(Conv2D(128, (3, 3),padding='valid',use_bias=True, kernel_initializer='glorot_uniform',bias_initializer='zeros',data_format= "channels_first"))
model.add(BatchNormalization())#axis=1))
model.add(Activation('relu'))
model.add(Conv2D(256, (3, 3),padding='valid',use_bias=True, kernel_initializer='glorot_uniform',bias_initializer='zeros',data_format= "channels_first"))
model.add(BatchNormalization())#axis=1))
model.add(Activation('relu'))
model.add(Conv2DTranspose(256, (1, 1),padding='valid',use_bias=True, kernel_initializer='glorot_uniform',bias_initializer='zeros',data_format= "channels_first"))
model.add(BatchNormalization())#axis=1))
model.add(Activation('relu'))
model.add(Conv2DTranspose(128, (3,3),padding='valid',use_bias=True, kernel_initializer='glorot_uniform',bias_initializer='zeros',data_format= "channels_first"))
model.add(BatchNormalization())#axis=1))
model.add(Activation('relu'))
model.add(Conv2DTranspose(64, (3,3),padding='valid',use_bias=True, kernel_initializer='glorot_uniform',bias_initializer='zeros',data_format= "channels_first"))
model.add(BatchNormalization())#axis=1))
model.add(Activation('relu'))
model.add(Conv2DTranspose(64, (5,5),padding='valid',use_bias=True, kernel_initializer='glorot_uniform',bias_initializer='zeros',data_format= "channels_first"))
model.add(BatchNormalization())#axis=1))
model.add(Activation('relu'))
model.add(Conv2DTranspose(1, (5, 5),padding='valid',use_bias=True, kernel_initializer='glorot_uniform',bias_initializer='zeros',data_format= "channels_first"))
model.add(BatchNormalization())#axis=1))
model.add(Activation('relu'))


model.summary()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0804 21:12:57.306284 140346368427904 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0804 21:12:57.359398 140346368427904 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0804 21:12:57.375969 140346368427904 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0804 21:12:57.391863 140346368427904 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0804 21:12:57.393123 140346368427904 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0804 21:13:00.303989 140346368427904 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 64, 125, 13)       12864
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64, 125, 13)       52
# _________________________________________________________________
# activation_1 (Activation)    (None, 64, 125, 13)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 121, 9)        102464
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 64, 121, 9)        36
# _________________________________________________________________
# activation_2 (Activation)    (None, 64, 121, 9)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 128, 119, 7)       73856
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128, 119, 7)       28
# _________________________________________________________________
# activation_3 (Activation)    (None, 128, 119, 7)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 256, 117, 5)       295168
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 256, 117, 5)       20
# _________________________________________________________________
# activation_4 (Activation)    (None, 256, 117, 5)       0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 256, 117, 5)       65792
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 256, 117, 5)       20
# _________________________________________________________________
# activation_5 (Activation)    (None, 256, 117, 5)       0
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 128, 119, 7)       295040
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 128, 119, 7)       28
# _________________________________________________________________
# activation_6 (Activation)    (None, 128, 119, 7)       0
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, 64, 121, 9)        73792
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 64, 121, 9)        36
# _________________________________________________________________
# activation_7 (Activation)    (None, 64, 121, 9)        0
# _________________________________________________________________
# conv2d_transpose_4 (Conv2DTr (None, 64, 125, 13)       102464
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 64, 125, 13)       52
# _________________________________________________________________
# activation_8 (Activation)    (None, 64, 125, 13)       0
# _________________________________________________________________
# conv2d_transpose_5 (Conv2DTr (None, 1, 129, 17)        1601
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 1, 129, 17)        68
# _________________________________________________________________
# activation_9 (Activation)    (None, 1, 129, 17)        0
# =================================================================
# Total params: 1,023,381
# Trainable params: 1,023,211
# Non-trainable params: 170
# _________________________________________________________________

# %% [markdown]
# #### Setup callback method for early stopping

# %%
early_stopping_monitor = EarlyStopping(monitor='val_loss',
                                       patience=5,
                                       verbose=2,
                                       restore_best_weights=True)

# %% [markdown]
# ## Model Compilation and training

# %%
model.compile(loss=keras.losses.mean_squared_error,
                  optimizer=keras.optimizers.Adam(lr=0.01, beta_1=0.9, beta_2=0.999),
                  metrics=['accuracy'])

history = model.fit(X_train,y_train,
                    batch_size=256,
                    epochs=200,
                    validation_split=0.2,
                    shuffle = True,
                    callbacks=[early_stopping_monitor])
# Out:
# W0804 21:13:05.932245 140346368427904 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# Train on 25600 samples, validate on 6400 samples
# Epoch 1/200

# %% [markdown]
# ## Saving model and its training history

# %%
model.save("drive/My Drive/Project/Models/Denoise/CED/cnn_model_param_348,085_val_loss_7141.9082_val_acc_0.1661_keras.h5")
pickle.dump(model.history.history, open('drive/My Drive/Project/Models/Denoise/CED/history_cnn_model_param_348,085_val_loss_7141.9082_val_acc_0.1661_keras.pkl', 'wb'))

# %% [markdown]
# ## Loading trained model for prediction and analysis

# %%
model = load_model("drive/My Drive/Project/Models/Denoise/CED/cnn_model_param_348,085_val_loss_7141.9082_val_acc_0.1661_keras.h5")

# %% [markdown]
# #### Model architecture plot

# %%
from IPython.display import SVG
from tensorflow.keras.utils import plot_model
plot_model(model, to_file="drive/My Drive/Project/Denoise/CED/ced_architecture.png")

# %% [markdown]
# ## Model evalution and analysis

# %%
val_loss, val_acc = model.evaluate(X_test, y_test)

# %% [markdown]
# ### Accuracy Score

# %%
print(f'Validation loss of Model : {val_loss}')
print(f'Validation accuracy of Model : {val_acc}')

# %% [markdown]
# ### Model training vs validation loss plot

# %%
pickle.load(open('drive/My Drive/Project/Models/Denoise/CED/history_cnn_model_param_348,085_val_loss_7141.9082_val_acc_0.1661_keras.pkl', 'rb'))

# %%
train_loss = history['loss']
train_acc = history['acc']
val_loss = history['val_loss']
val_acc = history['val_acc']

# %%
plt.plot(train_loss, label='Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training vs Validation Loss (RESNET)')
plt.plot(val_loss, label='Validation Loss')
plt.legend()
plt.savefig("drive/My Drive/Project/Models/Denoise/RESNET/loss_graph_resnet_model.png")
plt.show()
